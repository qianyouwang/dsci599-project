# %%
import scapy.all as sp
from scapy.all import rdpcap, TCP, IP
from decimal import Decimal, getcontext
import numpy as np
import pandas as pd
import glob
import os
import dnslib
import concurrent.futures

# %% [markdown]
# ## Iterating through a pcap trace

# %%
pcap_file = "RequetDataSet/A/PCAP_FILES/baseline_Jan17_exp_30.pcap"
# Load the pcap into memory
trace = sp.rdpcap(pcap_file)
# Iterate over the first ten packets
for packet in trace[:1]:
  # Print the IP HEADER
  if packet.haslayer(sp.IP):
    packet.show()
  if sp.TCP in packet:
    print(str(packet[sp.TCP])[:4*packet[sp.TCP].dataofs])

# Try print the TCP Header Only
# Out:
# ###[ Ethernet ]###
#   dst       = b8:8d:12:10:aa:8e
#   src       = 14:91:82:29:3b:57
#   type      = IPv4
# ###[ IP ]###
#      version   = 4
#      ihl       = 5
#      tos       = 0x0
#      len       = 60
#      id        = 0
#      flags     = DF
#      frag      = 0
#      ttl       = 64
#      proto     = tcp
#      chksum    = 0xb6ac
#      src       = 192.168.1.1
#      dst       = 192.168.1.190
#      \options   \
# ###[ TCP ]###
#         sport     = microsoft_ds
#         dport     = 52202
#         seq       = 1667711449
#         ack       = 3063488696
#         dataofs   = 10
#         reserved  = 0
#         flags     = SAE
#         window    = 14480
#         chksum    = 0xba18
#         urgptr    = 0
#         options   = [('MSS', 1460), ('SAckOK', b''), ('Timestamp', (6670394, 1021018435)), ('NOP', None), ('WScale', b'')]
#
# TCP 192.168.1.1:microsoft_ds > 192.168.1

# %%
with sp.PcapReader(pcap_file) as trace:
    count = 0
    for packet in trace:
        count += 1
    print(f"Total packets read: {count}")
# Out:
# Total packets read: 111795

# %%
with sp.PcapReader(pcap_file) as trace:
    for packet in trace:
        if packet.haslayer(sp.UDP) and packet[sp.UDP].sport == 53:
            print("DNS response packet found")
            break

    print("No DNS response packet")
# Out:
# DNS response packet found
# No DNS response packet

# %%
import json
from decimal import Decimal

def feature_extract_txt(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()

        # Metrics Initialization
        filename = file_path.split('/')[-1]
        total_bytes = 0
        chunks = []
        inter_arrival_times = []
        last_time = 0.0

        # Process each line
        for line in lines:
            data = json.loads(line.strip())
            relative_time = float(data[0])  # End of the interval in seconds
            packets_sent = int(data[1])
            packets_received = int(data[2])
            bytes_sent = int(data[3])
            bytes_received = int(data[4])
            network_info = data[5]  # List of lists with network info
            playback_info = data[6]  # Playback info list

            # Compute total bytes sent in the session (assuming total bytes are the sum of bytes sent)
            total_bytes += bytes_sent

            # Chunk size here can be defined as the bytes sent in each interval
            chunks.append(bytes_sent)

            # Calculate inter-arrival times (assuming 'relative_time' is in seconds and represents the end of each 100ms interval)
            if last_time != 0:
                inter_arrival_time = relative_time - last_time
                inter_arrival_times.append(inter_arrival_time)
            last_time = relative_time

        # Calculate metrics
        average_bytes_per_chunk = np.mean(chunks) if chunks else 0
        max_bytes_per_chunk = np.max(chunks) if chunks else 0
        min_bytes_per_chunk = np.min(chunks) if chunks else 0
        std_bytes_per_chunk = np.std(chunks) if chunks else 0

        # Assuming no retransmissions in this format
        retransmitted_chunk_numbers = 0

        # Bitrate (bytes per second)
        total_time = relative_time  # last recorded relative_time
        bitrate = (total_bytes / total_time) * 8 if total_time > 0 else 0  # Convert bytes to bits for bitrate

        # Time-based metrics (in seconds)
        average_time_between_chunks = np.mean(inter_arrival_times) if inter_arrival_times else 0
        std_time_between_chunks = np.std(inter_arrival_times) if inter_arrival_times else 0

        # Return computed metrics
        return [
            filename, total_bytes,
            average_bytes_per_chunk, max_bytes_per_chunk, min_bytes_per_chunk, std_bytes_per_chunk,
            0, 0,  # Placeholder for average and std transfer time as it's not applicable here
            average_time_between_chunks, std_time_between_chunks,
            retransmitted_chunk_numbers, bitrate
        ]

    except Exception as e:
        print(f'Error handling file {filename}: {e}')
        return None


# Example usage:
features = feature_extract_txt('./RequetDataSet/A/MERGED_FILES/baseline_Jan17_exp_30_merged.txt')
print(features)
# Out:
# Error handling file baseline_Jan17_exp_30_merged.txt: Expecting ',' delimiter: line 1 column 29 (char 28)
# None

# %% [markdown]
# ## BASIC packets analysis

# %%
def feature_extract(pcap_file):

    def decimal_mean(values):
        """Calculate the mean of a list of Decimal values."""
        total = sum(values)
        count = Decimal(len(values))
        return total / count
    
    def decimal_std(values):
        """Calculate the mean of a list of Decimal values."""
        total = sum(values)
        count = Decimal(len(values))
        
        mean = total/ count
        var = sum((x - mean) ** 2 for x in values) / len(values)
        std = var.sqrt()
        return std
    
    filename = pcap_file.split('/')[-1]

    # Load the pcap file
    try: 
        packets = rdpcap(pcap_file)

        # Filter TCP packets related to video streaming
        tcp_packets = [pkt for pkt in packets if TCP in pkt and IP in pkt]

        # Define lists to store data for analysis
        chunk_sizes = []
        inter_arrival_times = []
        transfer_times = []
        retransmissions = set()

        total_bits = 0
        start_time = float('inf')
        end_time = float('-inf')

        # Tracking variables
        last_ack = 0
        last_seq = {}
        last_time = tcp_packets[0].time
        chunk_start_time = None

        # Analyzing packets
        for i, packet in enumerate(tcp_packets):
            if TCP in packet:
                total_bits += len(packet[
                                TCP].payload) * 8  # Convert bytes to bits
                start_time = min(start_time, packet.time)
                end_time = max(end_time, packet.time)
            
            seq = packet[TCP].seq
            ack = packet[TCP].ack
            length = len(packet[TCP].payload)
            time = packet.time

            # Track retransmissions
            if seq in last_seq and time - last_seq[seq] < 1:
                retransmissions.add(seq)

            last_seq[seq] = time

            # Track chunk sizes and transfer times
            if ack > last_ack:
                if chunk_start_time is not None:
                    transfer_time = time - chunk_start_time
                    transfer_times.append(transfer_time)
                
                chunk_size = ack - last_ack
                chunk_sizes.append(chunk_size)
                
                inter_arrival_time = time - last_time
                inter_arrival_times.append(inter_arrival_time)
                
                chunk_start_time = time
                last_time = time

            last_ack = ack

        # Calculate desired metrics
        total_bytes = sum(chunk_sizes)
        max_bytes_per_chunk = np.max(chunk_sizes) if chunk_sizes else 0
        min_bytes_per_chunk = np.min(chunk_sizes) if chunk_sizes else 0
        std_bytes_per_chunk = np.std(chunk_sizes),
        average_bytes_per_chunk = np.mean(chunk_sizes) if chunk_sizes else 0
        average_transfer_time = decimal_mean(transfer_times) if transfer_times else 0
        std_transfer_time = decimal_std(transfer_times) if transfer_times else 0
        average_time_between_chunks = decimal_mean(inter_arrival_times[1:]) if len(inter_arrival_times) > 1 else 0  # Skip first
        std_time_between_chunks = decimal_std(inter_arrival_times[1:]) if len(inter_arrival_times) > 1 else 0
        retransmitted_chunk_numbers = len(retransmissions)

        total_duration = end_time - start_time

        # Calculate the bitrate in bits per second
        if total_duration > 0:
            bitrate = total_bits / total_duration
        else:
            bitrate = 0
        
        
        if chunk_sizes:
            last_10_chunk_sizes = chunk_sizes[-10:]  # Get the last 10 or fewer chunk sizes
            avg_last_10 = np.mean(last_10_chunk_sizes)
            max_last_10 = np.max(last_10_chunk_sizes)
            min_last_10 = np.min(last_10_chunk_sizes)
            std_last_10 = np.std(last_10_chunk_sizes)
            
            
        perc_50, perc_75, perc_85, perc_90 = np.percentile(last_10_chunk_sizes, [50, 75, 85, 90])
            

        return [filename, total_bytes, 
                average_bytes_per_chunk, max_bytes_per_chunk, min_bytes_per_chunk, std_bytes_per_chunk, 
                average_transfer_time, std_transfer_time, 
                average_time_between_chunks, std_time_between_chunks, 
                retransmitted_chunk_numbers, bitrate,
                avg_last_10, max_last_10, min_last_10, std_last_10, 
                perc_50, perc_75, perc_85, perc_90]
    
    except Exception as e:
        print(f'Error handling file {filename}: {e}')
        return None
        

    # Print the results
    # print("Total Bytes:", total_bytes)
    # print("Average Bytes per Chunk:", average_bytes_per_chunk)
    # print("Average Chunk Transfer Time:", average_transfer_time)
    # print("Average Time Elapsed Between Chunks:", average_time_between_chunks)
    # print("Retransmitted Chunk Numbers:", retransmitted_chunk_numbers)
    # print(f"Estimated Video Bitrate: {bitrate} bits per second")

# Further handling to calculate GET request response time
# This requires identifying HTTP GET requests and their corresponding responses, which would involve deeper packet inspection and protocol-specific parsing.

# %%
Decimal(Decimal(36681662874368))
# Out:
# Decimal('36681662874368')

# %%
df = pd.DataFrame(columns=['name', 'total_bytes', 
                           'average_bytes_per_chunk', 'max_bytes_per_chunk', 'min_bytes_per_chunk', 'std_bytes_per_chunk', 
                           'average_transfer_time', 'std_transfer_time',
                           'average_time_between_chunks', 'std_time_between_chunks', 
                           'retransmitted_chunk_numbers', 'bitrate'])

# %%
files = glob.glob("PCAP_FILES/baseline_*.pcap")

# %%
files
# Out:
# ['PCAP_FILES/baseline_Jan17_exp_28.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_30.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_31.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_32.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_33.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_34.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_36.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_37.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_38.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_39.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_40.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_41.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_42.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_43.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_44.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_45.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_47.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_48.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_49.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_50.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_51.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_52.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_53.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_54.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_55.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_59.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_63.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_66.pcap',
#  'PCAP_FILES/baseline_Jan17_exp_67.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_100.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_102.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_103.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_104.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_105.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_106.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_107.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_68.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_69.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_70.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_71.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_72.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_73.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_74.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_75.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_76.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_77.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_78.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_79.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_80.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_81.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_84.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_85.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_86.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_87.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_88.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_89.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_90.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_91.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_92.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_93.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_94.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_96.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_97.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_98.pcap',
#  'PCAP_FILES/baseline_Mar01_exp_99.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_100.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_101.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_103.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_105.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_106.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_107.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_68.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_69.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_70.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_71.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_74.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_77.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_78.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_79.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_81.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_82.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_83.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_84.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_85.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_86.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_88.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_89.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_90.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_91.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_92.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_93.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_94.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_96.pcap',
#  'PCAP_FILES/baseline_Mar02_exp_99.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_28.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_29.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_31.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_32.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_33.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_34.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_35.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_36.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_37.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_38.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_39.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_40.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_41.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_42.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_44.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_45.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_46.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_47.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_48.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_49.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_50.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_51.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_52.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_53.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_54.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_56.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_57.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_59.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_60.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_62.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_63.pcap',
#  'PCAP_FILES/baseline_Mar05_exp_66.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_109.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_110.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_111.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_112.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_113.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_116.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_117.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_118.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_119.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_120.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_121.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_122.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_124.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_125.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_126.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_129.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_130.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_131.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_132.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_133.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_134.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_135.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_136.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_137.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_139.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_140.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_141.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_142.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_143.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_144.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_145.pcap',
#  'PCAP_FILES/baseline_Mar06_exp_146.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_148.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_150.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_151.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_152.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_153.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_154.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_156.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_157.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_158.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_159.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_160.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_161.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_162.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_163.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_164.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_165.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_166.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_167.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_168.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_169.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_170.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_171.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_172.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_173.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_174.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_175.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_176.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_177.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_178.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_179.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_180.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_182.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_183.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_184.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_185.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_186.pcap',
#  'PCAP_FILES/baseline_Mar15_exp_187.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_188.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_190.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_191.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_193.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_194.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_196.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_197.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_199.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_200.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_201.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_202.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_203.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_204.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_205.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_206.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_207.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_208.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_209.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_210.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_211.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_213.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_214.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_215.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_216.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_217.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_218.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_219.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_220.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_221.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_223.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_224.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_226.pcap',
#  'PCAP_FILES/baseline_Mar16_exp_227.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_228.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_229.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_230.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_231.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_233.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_234.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_235.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_236.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_237.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_238.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_239.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_242.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_243.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_244.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_245.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_246.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_247.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_248.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_249.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_251.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_252.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_253.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_254.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_255.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_256.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_257.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_258.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_259.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_260.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_261.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_262.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_263.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_264.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_265.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_266.pcap',
#  'PCAP_FILES/baseline_Mar19_exp_267.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_108.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_109.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_111.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_112.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_113.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_114.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_115.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_116.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_117.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_118.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_119.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_120.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_121.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_122.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_123.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_125.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_126.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_127.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_128.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_130.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_131.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_132.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_133.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_134.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_135.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_136.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_138.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_139.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_140.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_141.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_142.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_143.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_144.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_145.pcap',
#  'PCAP_FILES/baseline_Mar20_exp_147.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_28.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_30.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_31.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_32.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_34.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_35.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_36.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_37.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_38.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_39.pcap',
#  'PCAP_FILES/baseline_Mar21_exp_43.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_28.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_29.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_30.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_31.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_32.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_33.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_34.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_35.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_36.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_37.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_38.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_40.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_41.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_42.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_43.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_44.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_45.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_46.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_48.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_49.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_50.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_51.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_52.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_53.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_54.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_55.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_56.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_57.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_58.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_59.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_60.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_61.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_62.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_63.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_64.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_65.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_66.pcap',
#  'PCAP_FILES/baseline_Mar22_exp_67.pcap']

# %%
feature_extract("PCAP_FILES/baseline_Jan17_exp_28.pcap")
# Out:
# ['baseline_Jan17_exp_28.pcap',
#  36681662874368,
#  1424475277.6345773,
#  4258675425,
#  1,
#  (859804874.4324368,),
#  Decimal('0.02319903801941747572815533981'),
#  Decimal('0.1436065685039621573197830741'),
#  Decimal('0.02319903801941747572815533981'),
#  Decimal('0.1436065685039621573197830741'),
#  1043,
#  Decimal('3492.511011121613018680525803')]

# %%
files = glob.glob("RequetDataSet/A/PCAP_FILES/baseline_*.pcap")

import os

num_cpus = os.cpu_count()

with concurrent.futures.ProcessPoolExecutor(max_workers=max(6, num_cpus // 2)) as executor:
# filename = './RequetDataSet/A/PCAP_FILES/baseline_Jan17_exp_30.pcap'
    # with open(filename, 'rb') as f: 
    results = list(executor.map(feature_extract, files))
    # row_list1.append(newline)
# Out:
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# Cell In[50], line 10
#       5 num_cpus = os.cpu_count()
#       7 with concurrent.futures.ProcessPoolExecutor(max_workers=max(6, num_cpus // 2)) as executor:
#       8 # filename = './RequetDataSet/A/PCAP_FILES/baseline_Jan17_exp_30.pcap'
#       9     # with open(filename, 'rb') as f:
# ---> 10     results = list(executor.map(feature_extract, files))
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/process.py:562, in _chain_from_iterable_of_lists(iterable)
#     556 def _chain_from_iterable_of_lists(iterable):
#     557     """
#     558     Specialized implementation of itertools.chain.from_iterable.
#     559     Each item in *iterable* should be a list.  This function is
#     560     careful not to keep references to yielded objects.
#     561     """
# --> 562     for element in iterable:
#     563         element.reverse()
#     564         while element:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
results
# Out:
# <generator object _chain_from_iterable_of_lists at 0x7fb92d45a7b0>

# %%
len(row_list1)
# Out:
# 32

# %% [markdown]
# ## Identifying the service type using DNS traffic

# %%
## DNS queries can be used to identify to which service a remote IP belongs to.

# %%
import scapy.all as sp
import dnslib

# YT for example
YT_DOMAINS = ["youtube"]

# READ THE PCAP AND INSERT INTO THIS ARRAY THE IP ADDRESS THAT BELONG TO YT
youtube_ips = []

pcap_file = "data/1659055888-c0.ipsecptp.tiered.pharos-ipsecptp-a-video.720.dash.http2.pcap"

with sp.PcapReader(pcap_file) as trace:
  for packet in trace:
    # DNS Packet
    if packet.haslayer(sp.UDP) and packet[sp.UDP].sport == 53:
      # Get DNS data
      raw = sp.raw(packet[sp.UDP].payload)
      # Process the DNS query
      dns = dnslib.DNSRecord.parse(raw)
      # Iterate over answers
      for a in dns.rr:
        # Check if it's a domain of interest
        question = str(a.rname)
        if any(s in question for s in youtube):
          # Check if it's an answer
          if a.rtype == 1 or a.rtype == 28:
            print("Query {} is a Youtube query. Appending IP {} to Youtube IPs".format(question, a.rdata))
            youtube_ips.append(str(a.rdata))

print("Youtube IPs: {}".format(youtube_ips))
# Out:
# Youtube IPs: []

# %%
import scapy.all as sp
import dnslib

all_domains_ips = {}

pcap_file = "data/1659055888-c0.ipsecptp.tiered.pharos-ipsecptp-a-video.720.dash.http2.pcap"

with sp.PcapReader(pcap_file) as trace:
    for packet in trace:
        if packet.haslayer(sp.UDP) and packet[sp.UDP].sport == 53:
            raw = sp.raw(packet[sp.UDP].payload)
            dns = dnslib.DNSRecord.parse(raw)
            for a in dns.rr:
                domain_name = str(a.rname)
                if a.rtype == 1 or a.rtype == 28:
                    if domain_name not in all_domains_ips:
                        all_domains_ips[domain_name] = []
                    all_domains_ips[domain_name].append(str(a.rdata))

for domain, ips in all_domains_ips.items():
    print(f"domain name：{domain}, IP addr: {ips}")

# %%
all_domains_ips
# Out:
# {}

# %% [markdown]
# ## Collecting network counters

# %%
network_counters = {}

# You can use this dictionary to collect counters
def counters():
  return {"in_pkts": 0, "out_pkts": 0, "in_bytes": 0, "out_bytes": 0}

# header is called "length"
pcap_file = "data/1659055888-c0.ipsecptp.tiered.pharos-ipsecptp-a-video.720.dash.http2.pcap"

with sp.PcapReader(pcap_file) as trace:
    for packet in trace:
        if packet.haslayer(sp.IP):
            src_ip = packet[sp.IP].src
            dst_ip = packet[sp.IP].dst
            pkt_length = packet[sp.IP].len

            if src_ip not in network_counters:
                network_counters[src_ip] = counters()
                
            network_counters[src_ip]["out_pkts"] += 1
            network_counters[src_ip]["out_bytes"] += pkt_length

            if dst_ip not in network_counters:
                network_counters[dst_ip] = counters()

            network_counters[dst_ip]["in_pkts"] += 1
            network_counters[dst_ip]["in_bytes"] += pkt_length

for ip in network_counters:
  print("IP {} generated the following amout of traffic {}".format(ip, network_counters[ip]))
# Out:
# IP 10.0.1.1 generated the following amout of traffic {'in_pkts': 338, 'out_pkts': 672, 'in_bytes': 94040, 'out_bytes': 182176}
# IP 10.0.13.1 generated the following amout of traffic {'in_pkts': 672, 'out_pkts': 338, 'in_bytes': 182176, 'out_bytes': 94040}
# IP 10.0.3.1 generated the following amout of traffic {'in_pkts': 73991, 'out_pkts': 37991, 'in_bytes': 110695512, 'out_bytes': 2076816}
# IP 10.0.15.1 generated the following amout of traffic {'in_pkts': 37991, 'out_pkts': 73991, 'in_bytes': 2076816, 'out_bytes': 110695512}

# %% [markdown]
# ## Infer segment downloads

# %%
## init seg. tracking
def segment():
    return {"pkts": 0, "bytes": 0}

# Read pcap and records completed video segments for each IP
completed_video_segments = {}
ongoing_video_segment = {}

with sp.PcapReader(pcap_file) as trace:
    for packet in trace:
        # Process only TCP packets that carry a payload
        if packet.haslayer(sp.TCP) and packet.haslayer(sp.IP):
            ip_len = packet[sp.IP].len
            ip_header_len = 4 * packet[sp.IP].ihl
            tcp_header_len = 4 * packet[sp.TCP].dataofs
            payload_size = ip_len - ip_header_len - tcp_header_len

            if payload_size > 0:
                src_ip = packet[sp.IP].src
                dst_ip = packet[sp.IP].dst

                # Assume packets to a Youtube IP are video segment downloads
                # This is a simplified check and would normally require more robust identification logic
                if dst_ip in youtube_ips:  
                    if dst_ip not in ongoing_video_segment:
                        ongoing_video_segment[dst_ip] = segment()
                    
                    ongoing_video_segment[dst_ip]["pkts"] += 1
                    ongoing_video_segment[dst_ip]["bytes"] += payload_size

                    # Example condition to mark a segment as completed (e.g., based on packet counts or bytes)
                    if ongoing_video_segment[dst_ip]["pkts"] >= 100:  # This threshold is arbitrary
                        if dst_ip not in completed_video_segments:
                            completed_video_segments[dst_ip] = []
                        completed_video_segments[dst_ip].append(ongoing_video_segment[dst_ip])
                        ongoing_video_segment[dst_ip] = segment()  # Reset for a new segment

# After capturing all segments, print the number of segments found for each Youtube IP
for ip in completed_video_segments.keys():
    print(f"IP {ip} downloaded {len(completed_video_segments[ip])} segments")

# %%
completed_video_segments, youtube_ips
# Out:
# ({}, [])
